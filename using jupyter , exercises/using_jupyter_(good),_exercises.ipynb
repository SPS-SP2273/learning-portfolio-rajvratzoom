# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %% [markdown]
# ## Exercise 1: Learning to interrupt

# %% [markdown]
# To interrupt this kernal I pressed the square button on the dashboard above, which interrupts the kernal
# and stop it from executing the code further

# %%
while True:
    print('*', end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 while True:
# ----> 2     print('*', end='')
#
# File ~\miniconda3\Lib\site-packages\ipykernel\iostream.py:683, in OutStream.write(self, string)
#     681 is_child = not self._is_master_process()
#     682 # only touch the buffer in the IO thread to avoid races
# --> 683 with self._buffer_lock:
#     684     self._buffers[frozenset(parent.items())].write(string)
#     685 if is_child:
#     686     # mp.Pool cannot be trusted to flush promptly (or ever),
#     687     # and this helps.
#
# KeyboardInterrupt:

# %% [markdown]
# ## Exercise 2: Resetting and Restarting the Kernal

# %%
print = 'PRINT'

# %% [markdown]
# The kernal above overrides the print function and assigns it to the string 'PRINT', as a result the kernal below initally could not print 'Hello world' and gave an error message. However after restarting the kernal below, the print function is reinstated and functions normally as shown below.

# %%
print('Hello World')
# Out:
# Hello World
